# %%
! pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Estatística
#
# * O que é estatística
# * Você lembra do IBGE
# * População = parâmetros
# * Amostra = estatística
# * Qual o tamanho da minha amostra

# %%
# Quero fazer uma pesquisa de funcionários, seus salários e te
# Questionários, entrevistas, primeiras análises percentuais
# Minha origem = população = parâmetros
# Minha origem = amostra = estatísticas

df_total = pd.read_csv("tempo_salarios.csv")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercício
#
# * copie e cole a imagem das variáveis e seus tipos
# * considere nosso dataset e informe para a turam quais os tipos de variáveis

# %% [markdown]
# # Quantitativos
# * Discretos: resultam de um conjunto finito ou enumerável de valores possíveis (contagens)
# * Contínuos: resultam em um número infinito de valores possíveis (mensurações)

# %% [markdown]
# # Estatística Descritiva
# * Medidas de Tendeência Central

# %%
df_total.describe()
# Out:
#        AnosdeExperiencia        Salario
# count          30.000000      30.000000
# mean            5.313333   76003.000143
# std             2.837888   27414.430032
# min             1.100000   37731.000000
# 25%             3.200000   56720.750000
# 50%             4.700000   65237.000000
# 75%             7.700000  100544.750000
# max            10.500000  122391.000000

# %%
df_faltando = pd.read_csv("tempo_salarios_copia_alterada.csv")

# %%
df_faltando.describe()
# Out:
#        AnosdeExperiencia      Salario
# count          30.000000     20.00000
# mean            5.313333  63704.85000
# std             2.837888  17970.62941
# min             1.100000  37731.00000
# 25%             3.200000  56092.75000
# 50%             4.700000  60630.50000
# 75%             7.700000  71294.25000
# max            10.500000  98273.00000
