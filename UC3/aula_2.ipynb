# %% [markdown]
# # Exercício - Estatística Descritiva (medida de tendência central)

# %% [markdown]
# # Um pesquisador ficou em determinado cruzamento durante 18 dias. Nesse cruzamento movimentado ele mediu o nível de ruído (decibéis). Calcular a média

# %%
# carregar o dataset
# calcular a media
# df.Campo.mean()
import pandas as pd

df_total = pd.read_csv("nivel_ruido.csv")

df_total.mean()
# Out:
# numero do dia           9.500000
# \tnivel ruido (dB)    108.444444
# dtype: float64
