# %% [markdown]
# # Inteligência Artificial

# %% [markdown]
# - A Inteligência Artificial é a imitação da vida
# - 1950: os primeiros computadores construindo a história da IA
# - Inverno da IA: empolgação seguida por uma desilusão
# - IA baseada em lógica foi perdendo espaço para uma IA baseada em Dados e Estatística
# - Machine Learning aplicado ao comércio
# - Redes Neurais, Big Data (Cloud Computer e Databricks)
# - "Maquina Viva": mitologia, Grecia Antiga, China
# - XVII: dispositivos "autômatos"
# - Filósofos - pensamento humano pode ser simulado por símbolos
# - Alan Turing (1912-1954): teste máquina de Turing (máquina tem ou não tem inteligência similar a humana)
# - Quem você considera inteligente:
#     - Linguística
#     - Artística
#     - Numérica
#     - Sensorial
#     - Espacial
#     - Física
#     - Reflexiva
# "Eu sei que sou inteligente, por que eu sei que nada sei" Sócrates

# %% [markdown]
# # IA no Cotidiano

# %% [markdown]
# - Navegação: Aplicativos de mapas sugerem rotas com base no trânsito em tempo real
# - Entretenimento: Plataformas de streaming recomendam conteúdo baseado em preferências
# - Assistentes virtuais: Facilitam interação com informações e conteúdos diversos
# - Reconhecimento de voz: Permite buscas e comandos por áudio

# %% [markdown]
# # O que é Inteligência Artificial?

# %% [markdown]
# - Definição: Conjunto de sistemas e tecnologias que resolvem problemas e realizam tarefas que normalmente exigiriam inteligência humana.
# - Área da ciência da computação dedicada à construção de soluções inteligentes
# - Utiliza racionalidade para realizar tarefas complexas
# - Processa linguagem natural e interpreta comandos verbais

# %% [markdown]
# # Origem da IA

# %% [markdown]
# - Anos 1950: Surgimento da IA como campo de estudo
# - Alan Turing: Pioneiro na pesquisa sobre máquinas pensantes
# - Teste de Turing (1950): Proposta para avaliar a inteligência de máquinas
# - Conferência de Dartmouth (1956): Termo "Inteligência Artificial" é oficialmente cunhado

# %% [markdown]
# # Redes Neurais

# %% [markdown]
# - Inspiração biológica: Baseadas no funcionamento do sistema nervoso humano
# - Estrutura: Camadas de neurônios artificiais interconectados que processam informações
# - Capacidades: Aprendizado com dados, identificação de padrões e tomada de decisões
# - Aplicações: Reconhecimento de imagem, processamento de linguagem natural, previsões

# %% [markdown]
# # IA Limitada

# %% [markdown]
# Definição
#
# - Sistemas que realizam tarefas específicas com excelência, mas limitados ao seu domínio de especialização
# Características
# - Foco em problemas específicos
# - Treinamento em conjuntos de dados direcionados
# - Sem consciência ou compreensão geral
#     - Exemplos:
#     Chatbots, sistemas de visão computacional, IA generativa (ChatGPT)

# %% [markdown]
# # IA Geral

# %% [markdown]
# - Em desenvolvimento
#     Definição
# - Sistemas com capacidade de realizar qualquer tarefa intelectual que um ser humano pode fazer
# Características
#     - Versatilidade em múltiplos domínios
#     - Capacidade de transferir conhecimento
#     - Adaptação a novas situações
#     - Raciocínio abstrato
# - Representações
#     Conceito explorado em ficção científica (Ex: filme "Ex Machina")

# %% [markdown]
# # Reflexão

# %% [markdown]
# - Com quantas aplicações que utilizam inteligência artificial você interagiu hoje?
#     - Assistentes virtuais em smartphones
#     - Filtros e efeitos em fotos
#     - Filtros de spam em e-mails
#     - Recomendações de músicas

# %% [markdown]
# # Data Driven

# %% [markdown]
# * Uma empresa orientada a Dados
# * Vocês já possuem os dados, mas utilizam em uma visão Data Driven:
# * Netflix
# * Spotify
# * Wall Mart

# %% [markdown]
# # A IA no seu dia a dia

# %% [markdown]
# * Google Maps
# * Waze
# * Netflix
# * Amazon Prime
# * Disney Plus
# * HBo

# %% [markdown]
# # Google Maps

# %% [markdown]
# - Probabilidade com diferentesw rotas
# - 4 possibilidades de caminhos

# %% [markdown]
# # Filmes

# %% [markdown]
# - Entretenimento sob demanda
# - Navegação em busca de um filme

# %% [markdown]
# # DataSet Games

# %% [markdown]
# - A importância do Dataset
# - Data Driven - uma cultura orientado a dados
# - EDA: análise exploratória de dados

# %%
! pip install pandas

# %%
# Importando o pandas
import pandas as pd

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# DataFrame
df_jogos = pd.read_csv ('dataset/steam-200k.csv')

# %%
df_jogos.head()
# Out:
#    151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 0  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 1  151603712                   Fallout 4  purchase    1.0  0
# 2  151603712                   Fallout 4      play   87.0  0
# 3  151603712                       Spore  purchase    1.0  0
# 4  151603712                       Spore      play   14.9  0

# %%
df_jogos.tail()
# Out:
#         151603712  The Elder Scrolls V Skyrim  purchase  1.0  0
# 199994  128470551                 Titan Souls      play  1.5  0
# 199995  128470551  Grand Theft Auto Vice City  purchase  1.0  0
# 199996  128470551  Grand Theft Auto Vice City      play  1.5  0
# 199997  128470551                        RUSH  purchase  1.0  0
# 199998  128470551                        RUSH      play  1.4  0

# %% [markdown]
# # Dataset Filmes

# %%
df_filmes = pd.read_csv ('dataset/filmes.csv.csv')
